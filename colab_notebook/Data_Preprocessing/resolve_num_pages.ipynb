# %%
import pandas as pd
import numpy as np

# %%
#Import dataset
books_data = pd.read_csv('D:/Uni Mannheim/Semester 2/Data Mining 2/DMC/publisher_author_cluster_added.csv', sep=',')
df = books_data.copy()
df.drop(['Unnamed: 0'], axis= 1, inplace=True)
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (8) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df.head(1)
# Out:
#    itemID                           title              author  \
# 0   21310  Princess Poppy: The Big Mix Up  Janey Louise Jones
#
#                             publisher main topic subtopics language  \
# 0  Penguin Random House Children's UK        YFB     [5AH]       en
#
#   interest_age                                        description  \
# 0            1  A brand-new story in the best-selling Princess...
#
#    publisher_cluster  author_cluster number_pages  \
# 0                  1            15.0         {''}
#
#                                   maintopic_text  \
# 0  Children’s / Teenage fiction: General fiction
#
#                      subtopics_text                        release_date
# 0  ['Interest age: from c 7 years']  {Timestamp('2010-11-30 00:00:00')}

# %%
for i in range (len(df.index)):
    string = str(df.at[i,'number_pages'])
    if "{'', 512}" in string:
        df.loc[i, 'number_pages'] = 512
    elif "{'', 216}" in string:
        df.loc[i, 'number_pages'] = 216
    elif "{960, ''}" in string:
        df.loc[i, 'number_pages'] = 960
    elif "{416, ''}" in string:
        df.loc[i, 'number_pages'] = 416
    elif "{'', 384}" in string:
        df.loc[i, 'number_pages'] = 384
    elif "{112, ''}" in string: 
        df.loc[i, 'number_pages'] = 112
    elif "{'', 176}" in string:
        df.loc[i, 'number_pages'] = 176
    elif "{'', 160}" in string:
        df.loc[i, 'number_pages'] = 160
    elif "{'', 278}" in string:
        df.loc[i, 'number_pages'] = 278
    elif "{432, ''}" in string:
        df.loc[i, 'number_pages'] = 432
    elif "{240, ''}" in string:
        df.loc[i, 'number_pages'] = 240
    elif "{'', 224}" in string:
        df.loc[i, 'number_pages'] = 224
    elif "{400, ''}" in string:
        df.loc[i, 'number_pages'] = 400
    elif "{'', 105}" in string:
        df.loc[i, 'number_pages'] = 105    
    elif "{'', 112}" in string:
        df.loc[i, 'number_pages'] = 112      
    elif "{'', 246}" in string:
        df.loc[i, 'number_pages'] = 246    
    elif "{688, ''}" in string:
        df.loc[i, 'number_pages'] = 688    
    elif "{896, ''}" in string:
        df.loc[i, 'number_pages'] = 896    
    elif "{'', 592}" in string:
        df.loc[i, 'number_pages'] = 592    
    elif "{'', 496}" in string:
        df.loc[i, 'number_pages'] = 496    
    elif "{'', 242}" in string:
        df.loc[i, 'number_pages'] = 242     
    elif "{'', 1520}" in string:
        df.loc[i, 'number_pages'] = 1520    
    elif "{32, ''}" in string:
        df.loc[i, 'number_pages'] = 32    
    elif "{'', 32}" in string:
        df.loc[i, 'number_pages'] = 32    
    elif "{80, ''}" in string:
        df.loc[i, 'number_pages'] = 80    
    elif "{'', 288}" in string:
        df.loc[i, 'number_pages'] = 288    
    elif "{'', 110}" in string:
        df.loc[i, 'number_pages'] = 110    
    elif "{'', 79}" in string:
        df.loc[i, 'number_pages'] = 79     
    elif "{'', 64}" in string:
        df.loc[i, 'number_pages'] = 64    
    elif "{'', 356}" in string:
        df.loc[i, 'number_pages'] = 356 
    elif "{'', 104}" in string:
        df.loc[i, 'number_pages'] = 104 
    elif "{'', 336}" in string:
        df.loc[i, 'number_pages'] = 336 
    elif "{'', 576}" in string:
        df.loc[i, 'number_pages'] = 576   
    elif "{'', 24}" in string:
        df.loc[i, 'number_pages'] = 24    
    elif "{352, ''}" in string:
        df.loc[i, 'number_pages'] = 352    
    elif "{'', 320}" in string:
        df.loc[i, 'number_pages'] = 320    
    elif "{320, ''}" in string:
        df.loc[i, 'number_pages'] = 320       
    elif "{'', 256}" in string:
        df.loc[i, 'number_pages'] = 256 
    elif "{448, ''}" in string:
        df.loc[i, 'number_pages'] = 448
    elif "{304, ''}" in string:
        df.loc[i, 'number_pages'] = 304    
    elif "{16, ''}" in string:
        df.loc[i, 'number_pages'] = 16
    elif "{'', 36}" in string:
        df.loc[i, 'number_pages'] = 36
    elif "{'', 372}" in string:
        df.loc[i, 'number_pages'] = 372
    elif "{'', 376}" in string:
        df.loc[i, 'number_pages'] = 376
    elif "{'', 296}" in string:
        df.loc[i, 'number_pages'] = 296    
    elif "{'', 96}" in string:
        df.loc[i, 'number_pages'] = 96      
    elif "{'', 234}" in string:
        df.loc[i, 'number_pages'] = 234
    elif "{'', 376}" in string:
        df.loc[i, 'number_pages'] = 376 
    elif '{656, 736, 688}' in string:
        df.loc[i, 'number_pages'] = 693    
    elif '{58, 92}' in string:
        df.loc[i, 'number_pages'] = 75  
    elif "{192, ''}" in string:
        df.loc[i, 'number_pages'] = 192 
    elif "{'', 68}" in string:
        df.loc[i, 'number_pages'] = 68 
    elif "{'', 448}" in string:
        df.loc[i, 'number_pages'] = 448 
    elif "{'', 432}" in string:
        df.loc[i, 'number_pages'] = 432 
    elif "{'', 254}" in string:
        df.loc[i, 'number_pages'] = 254 
    elif "{'', 350}" in string:
        df.loc[i, 'number_pages'] = 350
    elif "{'', 202}" in string:
        df.loc[i, 'number_pages'] = 202
    elif "{288, ''}" in string:
        df.loc[i, 'number_pages'] = 288
    elif "{'', 44}" in string:
        df.loc[i, 'number_pages'] = 44
    elif "{232, ''}" in string:
        df.loc[i, 'number_pages'] = 232
    elif "{'', 60}" in string:
        df.loc[i, 'number_pages'] = 60
    elif '{64, 10}' in string:
        df.loc[i, 'number_pages'] = 37 
    elif '{464, 79}' in string:
        df.loc[i, 'number_pages'] = 272 
    elif '{96, 480}' in string:
        df.loc[i, 'number_pages'] = 288 
    elif '{400, 176}' in string:
        df.loc[i, 'number_pages'] = 288 
    elif '{400, 72}' in string:
        df.loc[i, 'number_pages'] = 236 
    elif '{208, 123}' in string:
        df.loc[i, 'number_pages'] = 166    
    elif '{684, 604}'  in string:
        df.loc[i, 'number_pages'] = 644    
    elif '{672, 460}'  in string:
        df.loc[i, 'number_pages'] = 566            
    elif '{672, 448}'  in string:
        df.loc[i, 'number_pages'] = 560   
    elif '{272, 288}'  in string:
        df.loc[i, 'number_pages'] = 280    
    elif '{272, 178}'  in string:
        df.loc[i, 'number_pages'] = 225    
    elif '{204, 166}'  in string:
        df.loc[i, 'number_pages'] = 185    
    elif '{256, 64}'  in string:
        df.loc[i, 'number_pages'] = 160
    elif '{216, 1008, 288, 324}'  in string:
        df.loc[i, 'number_pages'] = 276
    elif '{480, 382}'  in string:
        df.loc[i, 'number_pages'] = 431
    elif '{432, 480}'  in string:
        df.loc[i, 'number_pages'] = 456
    elif '{480, 400}' in string:
        df.loc[i, 'number_pages'] = 440        
    elif '{208, 20}'  in string:
        df.loc[i, 'number_pages'] = 114        
    elif '{368, 320, 416}'  in string:
        df.loc[i, 'number_pages'] = 368
    elif '{112, 162, 246}'  in string:
        df.loc[i, 'number_pages'] = 174        
    elif "{'', 470}"  in string:
        df.loc[i, 'number_pages'] = 470           
    elif '{302, 182}'  in string:
        df.loc[i, 'number_pages'] = 242           
    elif '{16, 288}'  in string:
        df.loc[i, 'number_pages'] = 152   
    elif '{288, 338}'  in string:
        df.loc[i, 'number_pages'] = 313           
    elif '{392, 466, 352}'  in string:
        df.loc[i, 'number_pages'] = 403           
    elif '{288, 1008, 312}'  in string:
        df.loc[i, 'number_pages'] = 300   
    elif '{248, 206}'  in string:
        df.loc[i, 'number_pages'] = 227           
    elif '{296, 362}'  in string:
        df.loc[i, 'number_pages'] = 329          
    elif '{448, 372}'  in string:
        df.loc[i, 'number_pages'] = 410          
    elif '{448, 224}'  in string:
        df.loc[i, 'number_pages'] = 336  
    elif '{360, 438}'  in string:
        df.loc[i, 'number_pages'] = 399  
    elif '{544, 448}'  in string:
        df.loc[i, 'number_pages'] = 496  
    elif '{218, 298}'  in string:
        df.loc[i, 'number_pages'] = 258  
    elif '{250, 298}'  in string:
        df.loc[i, 'number_pages'] = 274  
    elif '{432, 448}'  in string:
        df.loc[i, 'number_pages'] = 440  
    elif '{304, 364}'  in string:
        df.loc[i, 'number_pages'] = 334  
    elif '{336, 304}'  in string:
        df.loc[i, 'number_pages'] = 320  

    elif '{400, 444}'  in string:
        df.loc[i, 'number_pages'] = 422 
    elif '{432, 400}'  in string:
        df.loc[i, 'number_pages'] = 416 
    elif '{120, 164}'  in string:
        df.loc[i, 'number_pages'] = 142 
    elif '{400, 584}'  in string:
        df.loc[i, 'number_pages'] = 492 
    elif '{624, 384}'  in string:
        df.loc[i, 'number_pages'] = 504 
    elif '{400, 480, 296}'  in string:
        df.loc[i, 'number_pages'] = 392 
    elif '{320, 384}'  in string:
        df.loc[i, 'number_pages'] = 352 
    elif '{240, 260}'  in string:
        df.loc[i, 'number_pages'] = 250         
    elif "{'', 52}"  in string:
        df.loc[i, 'number_pages'] = 52         
    elif "{'', 468}"  in string:
        df.loc[i, 'number_pages'] = 468         
    elif "{'', 500}"  in string:
        df.loc[i, 'number_pages'] = 500 
    elif "{'', 264}"  in string:
        df.loc[i, 'number_pages'] = 264         
    elif "{'', 52}"  in string:
        df.loc[i, 'number_pages'] = 52         
    elif "{'', 114}"  in string:
        df.loc[i, 'number_pages'] = 114         

    elif '{536, 322, 212}'  in string:
        df.loc[i, 'number_pages'] = 357         
    elif '{360, 80, 412}'  in string:
        df.loc[i, 'number_pages'] = 386         
    elif '{96, 32}'  in string:
        df.loc[i, 'number_pages'] = 64         
    elif  '{56, 274}' in string:
        df.loc[i, 'number_pages'] = 160         
    elif "{'', 106}"  in string:
        df.loc[i, 'number_pages'] = 106         
    elif '{480, 412}'  in string:
        df.loc[i, 'number_pages'] = 446         
    elif "{'', 378}" in string:
        df.loc[i, 'number_pages'] = 378         
    elif "{'', 476}"  in string:
        df.loc[i, 'number_pages'] = 476         
    elif "{'', 34}"  in string:
        df.loc[i, 'number_pages'] = 34         
    elif '{450, 350}'  in string:
        df.loc[i, 'number_pages'] = 400         
    elif "{'', 38}"  in string:
        df.loc[i, 'number_pages'] = 38         
    elif "{'', 436}"  in string:
        df.loc[i, 'number_pages'] = 436         
    elif '{48, 52}'  in string:
        df.loc[i, 'number_pages'] = 50         
    elif '{48, 36}'  in string:
        df.loc[i, 'number_pages'] = 42         
 
    elif "{544, ''}"  in string:
        df.loc[i, 'number_pages'] = 544  
    elif "{'', 128}"  in string:
        df.loc[i, 'number_pages'] = 128  
    elif "{'', 240}"  in string:
        df.loc[i, 'number_pages'] = 240  
    elif "{'', 304}"  in string:
        df.loc[i, 'number_pages'] = 304  
    elif "{'', 188}"  in string:
        df.loc[i, 'number_pages'] = 188  
    elif "{'', 190}"  in string:
        df.loc[i, 'number_pages'] = 190  
    elif "{'', 290}"  in string:
        df.loc[i, 'number_pages'] = 290  
    elif '{320, 298}' in string:
        df.loc[i, 'number_pages'] = 309  
    elif '{320, 302}'  in string:
        df.loc[i, 'number_pages'] = 311 
    elif '{320, 300}'  in string:
        df.loc[i, 'number_pages'] = 310 
    elif '{200, 224}'  in string:
        df.loc[i, 'number_pages'] = 212 
    elif '{16, 64}'  in string:
        df.loc[i, 'number_pages'] = 40 
    elif '{24, 20}'  in string:
        df.loc[i, 'number_pages'] = 22 
    elif '{32, 24}'  in string:
        df.loc[i, 'number_pages'] = 28 
    elif '{200, 208}'  in string:
        df.loc[i, 'number_pages'] = 204 
    elif '{80, 40}'  in string:
        df.loc[i, 'number_pages'] = 60 
    elif '{106, 212}'  in string:
        df.loc[i, 'number_pages'] = 159 
    elif '{240, 208}'  in string:
        df.loc[i, 'number_pages'] = 224 
    elif '{208, 316}' in string:
        df.loc[i, 'number_pages'] = 262 
    elif '{768, 640}'  in string:
        df.loc[i, 'number_pages'] = 704 
    elif '{64, 76}' in string:
        df.loc[i, 'number_pages'] = 70 
    elif '{208, 218, 336}'  in string:
        df.loc[i, 'number_pages'] = 254 
    elif '{640, 416}'  in string:
        df.loc[i, 'number_pages'] = 528         
    elif '{380, 270}'  in string:
        df.loc[i, 'number_pages'] = 325         
    elif '{256, 208}'  in string:
        df.loc[i, 'number_pages'] = 232         
    elif '{304, 358}'  in string:
        df.loc[i, 'number_pages'] = 331 
        
    elif "{'', 466, 284}" in string:
        df.loc[i, 'number_pages'] = 375 
    elif '{64, 528}'  in string:
        df.loc[i, 'number_pages'] = 296 
    elif '{466, 282}'  in string:
        df.loc[i, 'number_pages'] = 374 
    elif '{282, 350}' in string:
        df.loc[i, 'number_pages'] = 316 
    elif '{176, 254}'  in string:
        df.loc[i, 'number_pages'] = 215 
    elif '{416, 656}'  in string:
        df.loc[i, 'number_pages'] = 536 
    elif '{416, 352}'  in string:
        df.loc[i, 'number_pages'] = 384 
    elif '{234, 310}'  in string:
        df.loc[i, 'number_pages'] = 272         
    elif '{192, 155}'  in string:
        df.loc[i, 'number_pages'] = 174         
    elif '{50, 300}'  in string:
        df.loc[i, 'number_pages'] = 175         
    elif "{'', 1968}"  in string:
        df.loc[i, 'number_pages'] = 1968         
    elif '{160, 172}'  in string:
        df.loc[i, 'number_pages'] = 166         
    elif '{176, 150}'  in string:
        df.loc[i, 'number_pages'] = 163         
    elif '{256, 176}'  in string:
        df.loc[i, 'number_pages'] = 216         
    elif '{240, 282}'  in string:
        df.loc[i, 'number_pages'] = 262         
    elif '{192, 176}'  in string:
        df.loc[i, 'number_pages'] = 184         
    elif '{104, 80}'  in string:
        df.loc[i, 'number_pages'] = 92         
    elif "{'', 219}"  in string:
        df.loc[i, 'number_pages'] = 219 
    elif '{400, 480}'  in string:
        df.loc[i, 'number_pages'] = 440 
    elif '{48, 46}'  in string:
        df.loc[i, 'number_pages'] = 47 
        
    elif '{310, 390}' in string:
        df.loc[i, 'number_pages'] = 350         
    elif '{512, 576}'  in string:
        df.loc[i, 'number_pages'] = 544 
    elif '{937, 1068}'  in string:
        df.loc[i, 'number_pages'] = 1003 
    elif  '{208, 212}'  in string:
        df.loc[i, 'number_pages'] = 210 
    elif '{144, 88}'  in string:
        df.loc[i, 'number_pages'] = 116 
    elif '{272, 144}'  in string:
        df.loc[i, 'number_pages'] = 208 
    elif '{28, 757}'  in string:
        df.loc[i, 'number_pages'] = 393 
    elif '{280, 336}'  in string:
        df.loc[i, 'number_pages'] = 308 
    elif '{176, 64}'  in string:
        df.loc[i, 'number_pages'] = 120 

    elif '{496, 400}'  in string:
        df.loc[i, 'number_pages'] = 448         
    elif '{24, 208}'  in string:
        df.loc[i, 'number_pages'] = 116 
    elif '{32, 528}'  in string:
        df.loc[i, 'number_pages'] = 280 
    elif '{352, 300}'  in string:
        df.loc[i, 'number_pages'] = 326 
    elif '{128, 42}'  in string:
        df.loc[i, 'number_pages'] = 85  
    elif '{496, 464}'   in string:
        df.loc[i, 'number_pages'] = 480   
    elif '{272, 32}'  in string:
        df.loc[i, 'number_pages'] = 152 
    elif '{224, 32}'  in string:
        df.loc[i, 'number_pages'] = 128         
    elif '{240, 220}'  in string:
        df.loc[i, 'number_pages'] = 230         
    elif '{1104, 1200}'  in string:
        df.loc[i, 'number_pages'] = 1152 
        
        
    elif '{106, 154}'  in string:
        df.loc[i, 'number_pages'] = 130 
    elif '{512, 560}'  in string:
        df.loc[i, 'number_pages'] = 536 
    elif '{352, 384}'  in string:
        df.loc[i, 'number_pages'] = 568 
    elif '{346, 350}'  in string:
        df.loc[i, 'number_pages'] = 348 
    elif  '{352, 332}'  in string:
        df.loc[i, 'number_pages'] = 342 
    elif '{364, 572}'  in string:
        df.loc[i, 'number_pages'] = 468 
    elif '{264, 257}'   in string:
        df.loc[i, 'number_pages'] = 260 
    elif '{48, 135}'  in string:
        df.loc[i, 'number_pages'] = 92 
    elif '{624, 736}'  in string:
        df.loc[i, 'number_pages'] = 680 
    elif '{320, 340}'  in string:
        df.loc[i, 'number_pages'] = 330 
    elif '{88, 236}'  in string:
        df.loc[i, 'number_pages'] = 162 
    elif '{240, 111}'  in string:
        df.loc[i, 'number_pages'] = 157 
    elif '{400, 494}'  in string:
        df.loc[i, 'number_pages'] = 447 
    elif '{32, 176}'  in string:
        df.loc[i, 'number_pages'] = 104 
    elif '{56, 320}'  in string:
        df.loc[i, 'number_pages'] = 188 
    elif '{240, 104}'  in string:
        df.loc[i, 'number_pages'] = 174 
    elif '{48, 64}'  in string:
        df.loc[i, 'number_pages'] = 56 
    elif "{'', 1536}"  in string:
        df.loc[i, 'number_pages'] = 1536                                                                                                                                          
    elif '{144, 126}'  in string:
        df.loc[i, 'number_pages'] = 135 
    elif '{128, 96}'  in string:
        df.loc[i, 'number_pages'] = 112 

    elif '{256, 376}'  in string:
        df.loc[i, 'number_pages'] = 316         
    elif '{256, 194}'  in string:
        df.loc[i, 'number_pages'] = 225 
    elif '{256, 192}'  in string:
        df.loc[i, 'number_pages'] = 228             
    elif '{352, 196, 534}'  in string:
        df.loc[i, 'number_pages'] = 360 
    elif '{264, 438}'  in string:
        df.loc[i, 'number_pages'] = 351         
    elif '{340, 222}'  in string:
        df.loc[i, 'number_pages'] = 281         
    elif '{356, 364}'  in string:
        df.loc[i, 'number_pages'] = 360 
        
    elif '{384, 96}'  in string:
        df.loc[i, 'number_pages'] = 240         
    elif '{96, 384}'  in string:
        df.loc[i, 'number_pages'] = 240         
    elif '{12, 382}'  in string:
        df.loc[i, 'number_pages'] = 197 
    elif '{224, 400}'  in string:
        df.loc[i, 'number_pages'] = 312         
    elif '{576, 310}' in string:
        df.loc[i, 'number_pages'] = 443         
    elif '{384, 580}'  in string:
        df.loc[i, 'number_pages'] = 482         
    elif '{384, 192}'  in string:
        df.loc[i, 'number_pages'] = 288         
    elif '{384, 152}'  in string:
        df.loc[i, 'number_pages'] = 268 
    elif '{352, 576}'  in string:
        df.loc[i, 'number_pages'] = 464 
    elif '{388, 228}'  in string:
        df.loc[i, 'number_pages'] = 308         
    elif '{112, 240}'  in string:
        df.loc[i, 'number_pages'] = 176 

    elif '{480, 531}'  in string:
        df.loc[i, 'number_pages'] = 506 
    elif '{480, 528}'  in string:
        df.loc[i, 'number_pages'] = 505 
    elif '{480, 464}'  in string:
        df.loc[i, 'number_pages'] = 472 
    elif '{116, 86}'  in string:
        df.loc[i, 'number_pages'] = 101         
    elif '{288, 1008}' in string:
        df.loc[i, 'number_pages'] = 648         
    elif '{312, 378}'  in string:
        df.loc[i, 'number_pages'] = 345         
    elif '{288, 378}'  in string:
        df.loc[i, 'number_pages'] = 333          
    elif '{320, 402}'  in string:
        df.loc[i, 'number_pages'] = 361          
    elif '{320, 112}'  in string:
        df.loc[i, 'number_pages'] = 216          
    elif '{106, 190}' in string:
        df.loc[i, 'number_pages'] = 154          
    elif '{252, 262}'  in string:
        df.loc[i, 'number_pages'] = 257  
    elif '{378, 293}'  in string:
        df.loc[i, 'number_pages'] = 335 
    elif '{378, 254}'  in string:
        df.loc[i, 'number_pages'] = 316 
    elif "{464, '', 262}"  in string:
        df.loc[i, 'number_pages'] = 363 

    elif '{466, 278}'  in string:
        df.loc[i, 'number_pages'] = 372 
    elif '{528, 368}'  in string:
        df.loc[i, 'number_pages'] = 448 
    elif '{544, 432}'  in string:
        df.loc[i, 'number_pages'] = 488 
    elif '{448, 544}'  in string:
        df.loc[i, 'number_pages'] = 496 
    elif '{544, 96}'  in string:
        df.loc[i, 'number_pages'] = 320 
    elif '{848, 50}'   in string:
        df.loc[i, 'number_pages'] = 449         
    elif '{380, 308}'  in string:
        df.loc[i, 'number_pages'] = 344         
    elif '{380, 182}'   in string:
        df.loc[i, 'number_pages'] = 279         
    elif '{368, 240}'  in string:
        df.loc[i, 'number_pages'] = 304         
    elif '{368, 248}'  in string:
        df.loc[i, 'number_pages'] = 308         
        
    elif '{472, 326}'  in string:
        df.loc[i, 'number_pages'] = 399          
    elif '{514, 358}'  in string:
        df.loc[i, 'number_pages'] = 436          
    elif '{236, 350}'  in string:
        df.loc[i, 'number_pages'] = 293  
    elif '{236, 158}'  in string:
        df.loc[i, 'number_pages'] = 197  
    elif '{202, 114}'  in string:
        df.loc[i, 'number_pages'] = 158  
    elif '{432, 318}'  in string:
        df.loc[i, 'number_pages'] = 375  

    elif '{504, 524}'  in string:
        df.loc[i, 'number_pages'] = 514  
    elif '{56, 88}'  in string:
        df.loc[i, 'number_pages'] = 72  
    elif '{536, 170}'  in string:
        df.loc[i, 'number_pages'] = 353  
    elif '{180, 284}'  in string:
        df.loc[i, 'number_pages'] = 232  
    elif '{432, 550}'  in string:
        df.loc[i, 'number_pages'] = 491          
    elif '{498, 359}' in string:
        df.loc[i, 'number_pages'] = 428          
    elif '{24, 428}'  in string:
        df.loc[i, 'number_pages'] = 226          
    elif '{272, 210}'  in string:
        df.loc[i, 'number_pages'] = 241          
    elif '{80, 299}'  in string:
        df.loc[i, 'number_pages'] = 190          
    elif '{24, 428}'   in string:
        df.loc[i, 'number_pages'] = 236          
    elif '{208, 192}'  in string:
        df.loc[i, 'number_pages'] = 200          
    elif '{360, 272}'  in string:
        df.loc[i, 'number_pages'] = 315          
    elif '{144, 208}'  in string:
        df.loc[i, 'number_pages'] = 176  
    elif '{272, 31}' in string:
        df.loc[i, 'number_pages'] = 152          
    elif '{232, 304}'  in string:
        df.loc[i, 'number_pages'] = 268          
    elif '{128, 352}'  in string:
        df.loc[i, 'number_pages'] = 240          
    elif '{184, 336}'  in string:
        df.loc[i, 'number_pages'] = 260          
    elif '{512, 282}'  in string:
        df.loc[i, 'number_pages'] = 397          
        
    elif '{160, 280}' in string:
        df.loc[i, 'number_pages'] = 220  
    elif '{578, 612}'  in string:
        df.loc[i, 'number_pages'] = 595          
    elif '{640, 216}' in string:
        df.loc[i, 'number_pages'] = 428          
    elif '{160, 436}'  in string:
        df.loc[i, 'number_pages'] = 298          
    elif '{336, 14}'  in string:
        df.loc[i, 'number_pages'] = 175          
    elif '{64, 144}'  in string:
        df.loc[i, 'number_pages'] = 104          
    elif '{440, 336}'  in string:
        df.loc[i, 'number_pages'] = 388          
    elif '{496, 226}'  in string:
        df.loc[i, 'number_pages'] = 361          
    elif '{72, 376}'   in string:
        df.loc[i, 'number_pages'] = 224     
    elif '{146, 226}'   in string:
        df.loc[i, 'number_pages'] = 186            
    elif '{464, 142}'   in string:
        df.loc[i, 'number_pages'] = 303            
    elif '{250, 342}'   in string:
        df.loc[i, 'number_pages'] = 296

# %%
import string
import re
for i in range (len(df.index)):
    num_page = str(df.at[i,'number_pages'])
    allow = string.digits
    num_page = re.sub('[^%s]' % allow, '', num_page)
    df.loc[i, 'number_pages'] = num_page

# %%
df1 = df[df['number_pages']== '']
df2 = df[df['number_pages']!= '']

# %%
df2 = df2.astype({'number_pages': 'int64'})

# %%
df1 = df1.replace(r'^\s*$', np.NaN, regex=True)

# %%
frames = [df1, df2]
df = pd.concat(frames)

# %%
df.count()
# Out:
# itemID               78030
# title                78030
# author               75824
# publisher            78030
# main topic           77772
# subtopics            78029
# language             78030
# interest_age         78030
# description          73728
# publisher_cluster    78030
# author_cluster       75824
# number_pages         66363
# maintopic_text       77772
# subtopics_text       41126
# release_date         78021
# dtype: int64

# %%
df.to_csv('publisher_author_cluster_added.csv')
